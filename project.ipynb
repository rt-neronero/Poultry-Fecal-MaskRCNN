# %% [markdown]
# # Setup

# %%
# !nvidia-smi
# Out:
# Wed Mar 26 01:26:13 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.36                 Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   48C    P5              5W /   25W |     639MiB /   6141MiB |     10%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      3940    C+G   ...155_x64__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A      7692    C+G   ...on\134.0.3124.83\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A      7916    C+G   ...al\Discord\app-1.0.9186\Discord.exe      N/A      |
# |    0   N/A  N/A      7988    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     11248    C+G   ...werToys\PowerToys.PowerLauncher.exe      N/A      |
# |    0   N/A  N/A     11308    C+G   ...\PowerToys\PowerToys.FancyZones.exe      N/A      |
# |    0   N/A  N/A     12048    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     14040    C+G   ...werToys\PowerToys.ColorPickerUI.exe      N/A      |
# |    0   N/A  N/A     15900    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     17536    C+G   ...155_x64__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A     19908    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A     24368    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A     24644    C+G   ...155_x64__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A     27432    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     29984    C+G   ...4.0_x64__w2gh52qy24etm\Nahimic3.exe      N/A      |
# |    0   N/A  N/A     29992    C+G   ...UI3Apps\PowerToys.AdvancedPaste.exe      N/A      |
# |    0   N/A  N/A     30380    C+G   ...ys\WinUI3Apps\PowerToys.Peek.UI.exe      N/A      |
# |    0   N/A  N/A     30424    C+G   ...on\134.0.3124.83\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     30448    C+G   ...cks-services\BlueStacksServices.exe      N/A      |
# |    0   N/A  N/A     31224    C+G   ...14.0_x64__zpdnekdrzrea0\Spotify.exe      N/A      |
# |    0   N/A  N/A     33560    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     35572    C+G   ....0_x64__kzh8wxbdkxb8p\DCv2\DCv2.exe      N/A      |
# |    0   N/A  N/A     38308    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip3 install -r requirements.txt -q

# %%
from tensorflow.keras import backend as K
print(K.backend())
# Out:
# tensorflow

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
import sys
import json
import datetime
import numpy as np
import skimage.draw
import cv2
from mrcnn.visualize import display_instances
import matplotlib.pyplot as plt
import imgaug
import time
from memory_profiler import memory_usage

try:
    from tensorflow.keras.callbacks import Callback  # TensorFlow < 2.14
except ImportError:
    from keras.callbacks import Callback  # TensorFlow 2.14+

from tqdm import tqdm
import skimage.io
import tensorflow as tf
import h5py
from tensorflow.python.keras.saving import hdf5_format
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

import warnings

# %%
tf.get_logger().setLevel('ERROR')
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # Model

# %% [markdown]
# ## Config

# %%
# Root directory of the project
ROOT_DIR = os.getcwd()
DATASET_DIR = os.path.join(ROOT_DIR, "dataset")

# %%
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# %%
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")

class CustomConfig(Config):
    """Configuration for training on the poultry feces dataset."""
    NAME = "class"

    GPU_COUNT = 1
    IMAGES_PER_GPU = 3

    IMAGE_MIN_DIM = 128
    IMAGE_MAX_DIM = 512

    # Number of classes (including background)
    NUM_CLASSES = 1 + 4  # Background + (cocci, healthy, ncd, salmo)

    STEPS_PER_EPOCH = 452 / IMAGES_PER_GPU
    VALIDATION_STEPS = 100 / IMAGES_PER_GPU
    # STEPS_PER_EPOCH = 100
    # VALIDATION_STEPS = 50

    DETECTION_MIN_CONFIDENCE = 0.9
    LEARNING_RATE = 0.001

# %%
config = CustomConfig()

# %% [markdown]
# ##  Dataset

# %%
CLASS_NAMES = ["BG", "cocci", "healthy", "ncd", "salmo"]

# %%
class CustomDataset(utils.Dataset):
    def load_custom(self, dataset_dir, subset):
        """Load a subset of the poultry feces dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("class", 1, "cocci")
        self.add_class("class", 2, "healthy")
        self.add_class("class", 3, "ncd")
        self.add_class("class", 4, "salmo")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)

        json_file = os.path.join(dataset_dir, f"{subset}_annotations.json")
        with open(json_file) as f:
          annotations1 = json.load(f)

        # print(annotations1)
        annotations = list(annotations1.values())
        annotations = [a for a in annotations if a['regions']]

        # Add images
        name_dict = {"cocci": 1, "healthy": 2, "ncd": 3, "salmo": 4}
        # for a in annotations:
        for a in tqdm(annotations, desc="Loading Images ..."):
            # print(a)
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. There are stores in the
            # shape_attributes (see json format above)
            polygons = [r['shape_attributes'] for r in a['regions']]
            classes = [s['region_attributes']['class'] for s in a['regions']]

            # key = tuple(name_dict)
            num_ids = [name_dict[a] for a in classes]

            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "class",  ## for a single class just add the name here
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                num_ids=num_ids
                )

    def load_mask(self, image_id):
        """Generate instance masks for an image."""
        image_info = self.image_info[image_id]
        if image_info["source"] != "class":
            return super(self.__class__, self).load_mask(image_id)

        if "polygons" not in image_info:
            print(f"Skipping image {image_info['path']} - No polygons found.")
            return np.zeros((image_info["height"], image_info["width"], 0), dtype=np.uint8), np.array([])

        num_ids = image_info['num_ids']
        mask = np.zeros([image_info["height"], image_info["width"], len(image_info["polygons"])], dtype=np.uint8)

        for i, p in enumerate(image_info["polygons"]):
            if "all_points_x" in p and "all_points_y" in p:  # Polygon Annotation
                rr, cc = skimage.draw.polygon(np.array(p['all_points_y']), np.array(p['all_points_x']))
            elif "name" in p and p["name"] == "ellipse":  # Ellipse Annotation
                cy, cx, ry, rx = p["cy"], p["cx"], p["ry"], p["rx"]
                rr, cc = skimage.draw.ellipse(cy, cx, ry, rx, shape=(image_info["height"], image_info["width"]))
            else:
                print(f"Skipping annotation with missing keys: {p}")
                continue  # Skip this polygon if missing required points

            # Clip to prevent out-of-bounds errors
            rr = np.clip(rr, 0, image_info["height"] - 1)
            cc = np.clip(cc, 0, image_info["width"] - 1)

            mask[rr, cc, i] = 1  # Assign mask values

        return mask.astype(bool), np.array(num_ids, dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "class":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %%
dataset_train = CustomDataset()
dataset_train.load_custom(DATASET_DIR, "train")
dataset_train.prepare()

dataset_val = CustomDataset()
dataset_val.load_custom(DATASET_DIR, "val")
dataset_val.prepare()
# Out:
# Loading Images ...: 100%|██████████| 958/958 [00:43<00:00, 22.08it/s]
# Loading Images ...: 100%|██████████| 240/240 [00:08<00:00, 27.87it/s]

# %% [markdown]
# ## Train

# %%
# Path to trained weights file
COCO_WEIGHTS_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
WEIGHTS_PATH = os.path.join(ROOT_DIR, "mask_rcnn_poultry.h5")

# %%
def train(model, dataset_train, dataset_val):
    """Train the model."""
    start_time = time.time()
    model.train(
            dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE,
            epochs=100,
            layers="heads",
            augmentation=imgaug.augmenters.Sequential([
                imgaug.augmenters.Grayscale(alpha=(0.0, 1.0)),
                imgaug.augmenters.AddToHueAndSaturation((-20, 20)),
                imgaug.augmenters.Add((-10, 10), per_channel=0.5),
                imgaug.augmenters.Invert(0.05, per_channel=True),
                imgaug.augmenters.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5))
            ])
        )
    model.keras_model.save_weights(WEIGHTS_PATH)
    print(f"\nModel saved at {WEIGHTS_PATH}\n")
    end_time = time.time()

    # Output training time and memory usage statistics
    print(f"Training time: {end_time - start_time:.2f} seconds")

# %%
model = modellib.MaskRCNN(mode="training", config=config, model_dir=DEFAULT_LOGS_DIR)

if os.path.exists(COCO_WEIGHTS_PATH):
    print("COCO weights found.\n")
    model.load_weights(COCO_WEIGHTS_PATH, by_name=True, exclude=[
            "mrcnn_class_logits", "mrcnn_bbox_fc",
            "mrcnn_bbox", "mrcnn_mask"])
elif os.path.exists(WEIGHTS_PATH):
    print("Poultry weights found.\n")
    model.load_weights(WEIGHTS_PATH, by_name=True)
else:
    print("No weights found. Training from scratch.\n")

train(model, dataset_train, dataset_val)
# Out:
# COCO weights found.
#
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: c:\Users\Artryan Nero Logarta\OneDrive - Mapúa University\24-25\2Q\MCS612\Automated-Poultry-Disease-Detection-from-Fecal-Images-Using-Mask-R-CNN\logs\class20250326T0127\mask_rcnn_class_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 1.6510 - rpn_class_loss: 0.0238 - rpn_bbox_loss: 0.4292 - mrcnn_class_loss: 0.2192 - mrcnn_bbox_loss: 0.5510 - mrcnn_mask_loss: 0.4278Max memory usage during epoch 1: 1020.14453125 MiB
# 150/150 [==============================] - 595s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 1.6510 - rpn_class_loss: 0.0238 - rpn_bbox_loss: 0.4292 - mrcnn_class_loss: 0.2192 - mrcnn_bbox_loss: 0.5510 - mrcnn_mask_loss: 0.4278 - val_loss: 1.2024 - val_rpn_class_loss: 0.0187 - val_rpn_bbox_loss: 0.2997 - val_mrcnn_class_loss: 0.1552 - val_mrcnn_bbox_loss: 0.4059 - val_mrcnn_mask_loss: 0.2995 - memory_usage: 1020.1445
# Epoch 2/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 1.2510 - rpn_class_loss: 0.0175 - rpn_bbox_loss: 0.3543 - mrcnn_class_loss: 0.1773 - mrcnn_bbox_loss: 0.3795 - mrcnn_mask_loss: 0.3224Max memory usage during epoch 2: 820.890625 MiB
# 150/150 [==============================] - 545s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 1.2510 - rpn_class_loss: 0.0175 - rpn_bbox_loss: 0.3543 - mrcnn_class_loss: 0.1773 - mrcnn_bbox_loss: 0.3795 - mrcnn_mask_loss: 0.3224 - val_loss: 1.2142 - val_rpn_class_loss: 0.0172 - val_rpn_bbox_loss: 0.3841 - val_mrcnn_class_loss: 0.1807 - val_mrcnn_bbox_loss: 0.3376 - val_mrcnn_mask_loss: 0.2707 - memory_usage: 820.8906
# Epoch 3/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 1.1261 - rpn_class_loss: 0.0172 - rpn_bbox_loss: 0.3136 - mrcnn_class_loss: 0.1610 - mrcnn_bbox_loss: 0.3383 - mrcnn_mask_loss: 0.2960Max memory usage during epoch 3: 733.09375 MiB
# 150/150 [==============================] - 527s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 1.1261 - rpn_class_loss: 0.0172 - rpn_bbox_loss: 0.3136 - mrcnn_class_loss: 0.1610 - mrcnn_bbox_loss: 0.3383 - mrcnn_mask_loss: 0.2960 - val_loss: 1.1575 - val_rpn_class_loss: 0.0157 - val_rpn_bbox_loss: 0.4035 - val_mrcnn_class_loss: 0.1247 - val_mrcnn_bbox_loss: 0.3161 - val_mrcnn_mask_loss: 0.2749 - memory_usage: 733.0938
# Epoch 4/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 1.0399 - rpn_class_loss: 0.0145 - rpn_bbox_loss: 0.3114 - mrcnn_class_loss: 0.1344 - mrcnn_bbox_loss: 0.2908 - mrcnn_mask_loss: 0.2888Max memory usage during epoch 4: 707.8515625 MiB
# 150/150 [==============================] - 530s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 1.0399 - rpn_class_loss: 0.0145 - rpn_bbox_loss: 0.3114 - mrcnn_class_loss: 0.1344 - mrcnn_bbox_loss: 0.2908 - mrcnn_mask_loss: 0.2888 - val_loss: 0.9818 - val_rpn_class_loss: 0.0133 - val_rpn_bbox_loss: 0.2677 - val_mrcnn_class_loss: 0.1400 - val_mrcnn_bbox_loss: 0.2732 - val_mrcnn_mask_loss: 0.2684 - memory_usage: 707.8516
# Epoch 5/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.9352 - rpn_class_loss: 0.0139 - rpn_bbox_loss: 0.2436 - mrcnn_class_loss: 0.1341 - mrcnn_bbox_loss: 0.2715 - mrcnn_mask_loss: 0.2721Max memory usage during epoch 5: 553.52734375 MiB
# 150/150 [==============================] - 517s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.9352 - rpn_class_loss: 0.0139 - rpn_bbox_loss: 0.2436 - mrcnn_class_loss: 0.1341 - mrcnn_bbox_loss: 0.2715 - mrcnn_mask_loss: 0.2721 - val_loss: 0.9846 - val_rpn_class_loss: 0.0143 - val_rpn_bbox_loss: 0.3049 - val_mrcnn_class_loss: 0.1130 - val_mrcnn_bbox_loss: 0.2633 - val_mrcnn_mask_loss: 0.2697 - memory_usage: 553.5273
# Epoch 6/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.9430 - rpn_class_loss: 0.0143 - rpn_bbox_loss: 0.2701 - mrcnn_class_loss: 0.1250 - mrcnn_bbox_loss: 0.2613 - mrcnn_mask_loss: 0.2724Max memory usage during epoch 6: 555.234375 MiB
# 150/150 [==============================] - 524s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.9430 - rpn_class_loss: 0.0143 - rpn_bbox_loss: 0.2701 - mrcnn_class_loss: 0.1250 - mrcnn_bbox_loss: 0.2613 - mrcnn_mask_loss: 0.2724 - val_loss: 0.9312 - val_rpn_class_loss: 0.0124 - val_rpn_bbox_loss: 0.2900 - val_mrcnn_class_loss: 0.1144 - val_mrcnn_bbox_loss: 0.2569 - val_mrcnn_mask_loss: 0.2393 - memory_usage: 555.2344
# Epoch 7/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.8842 - rpn_class_loss: 0.0120 - rpn_bbox_loss: 0.2326 - mrcnn_class_loss: 0.1174 - mrcnn_bbox_loss: 0.2521 - mrcnn_mask_loss: 0.2701Max memory usage during epoch 7: 558.2890625 MiB
# 150/150 [==============================] - 517s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.8842 - rpn_class_loss: 0.0120 - rpn_bbox_loss: 0.2326 - mrcnn_class_loss: 0.1174 - mrcnn_bbox_loss: 0.2521 - mrcnn_mask_loss: 0.2701 - val_loss: 0.9310 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.2741 - val_mrcnn_class_loss: 0.0988 - val_mrcnn_bbox_loss: 0.2648 - val_mrcnn_mask_loss: 0.2635 - memory_usage: 558.2891
# Epoch 8/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.8723 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.2530 - mrcnn_class_loss: 0.1041 - mrcnn_bbox_loss: 0.2360 - mrcnn_mask_loss: 0.2660Max memory usage during epoch 8: 566.35546875 MiB
# 150/150 [==============================] - 535s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.8723 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.2530 - mrcnn_class_loss: 0.1041 - mrcnn_bbox_loss: 0.2360 - mrcnn_mask_loss: 0.2660 - val_loss: 0.9504 - val_rpn_class_loss: 0.0125 - val_rpn_bbox_loss: 0.2766 - val_mrcnn_class_loss: 0.1018 - val_mrcnn_bbox_loss: 0.2622 - val_mrcnn_mask_loss: 0.2787 - memory_usage: 566.3555
# Epoch 9/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.8484 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 0.2416 - mrcnn_class_loss: 0.1083 - mrcnn_bbox_loss: 0.2269 - mrcnn_mask_loss: 0.2603Max memory usage during epoch 9: 567.0 MiB
# 150/150 [==============================] - 529s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.8484 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 0.2416 - mrcnn_class_loss: 0.1083 - mrcnn_bbox_loss: 0.2269 - mrcnn_mask_loss: 0.2603 - val_loss: 0.8815 - val_rpn_class_loss: 0.0117 - val_rpn_bbox_loss: 0.3314 - val_mrcnn_class_loss: 0.0737 - val_mrcnn_bbox_loss: 0.2292 - val_mrcnn_mask_loss: 0.2182 - memory_usage: 567.0000
# Epoch 10/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.8482 - rpn_class_loss: 0.0121 - rpn_bbox_loss: 0.2398 - mrcnn_class_loss: 0.1009 - mrcnn_bbox_loss: 0.2286 - mrcnn_mask_loss: 0.2667Max memory usage during epoch 10: 572.3125 MiB
# 150/150 [==============================] - 522s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.8482 - rpn_class_loss: 0.0121 - rpn_bbox_loss: 0.2398 - mrcnn_class_loss: 0.1009 - mrcnn_bbox_loss: 0.2286 - mrcnn_mask_loss: 0.2667 - val_loss: 0.9422 - val_rpn_class_loss: 0.0120 - val_rpn_bbox_loss: 0.3104 - val_mrcnn_class_loss: 0.0754 - val_mrcnn_bbox_loss: 0.2429 - val_mrcnn_mask_loss: 0.2831 - memory_usage: 572.3125
# Epoch 11/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.7850 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.2301 - mrcnn_class_loss: 0.0894 - mrcnn_bbox_loss: 0.2114 - mrcnn_mask_loss: 0.2434Max memory usage during epoch 11: 571.17578125 MiB
# 150/150 [==============================] - 511s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7850 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.2301 - mrcnn_class_loss: 0.0894 - mrcnn_bbox_loss: 0.2114 - mrcnn_mask_loss: 0.2434 - val_loss: 0.9121 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.2671 - val_mrcnn_class_loss: 0.0941 - val_mrcnn_bbox_loss: 0.2597 - val_mrcnn_mask_loss: 0.2626 - memory_usage: 571.1758
# Epoch 12/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.8458 - rpn_class_loss: 0.0127 - rpn_bbox_loss: 0.2670 - mrcnn_class_loss: 0.0999 - mrcnn_bbox_loss: 0.2175 - mrcnn_mask_loss: 0.2487Max memory usage during epoch 12: 505.77734375 MiB
# 150/150 [==============================] - 526s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.8458 - rpn_class_loss: 0.0127 - rpn_bbox_loss: 0.2670 - mrcnn_class_loss: 0.0999 - mrcnn_bbox_loss: 0.2175 - mrcnn_mask_loss: 0.2487 - val_loss: 0.7929 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.2392 - val_mrcnn_class_loss: 0.0810 - val_mrcnn_bbox_loss: 0.2248 - val_mrcnn_mask_loss: 0.2222 - memory_usage: 505.7773
# Epoch 13/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.7910 - rpn_class_loss: 0.0117 - rpn_bbox_loss: 0.2220 - mrcnn_class_loss: 0.0935 - mrcnn_bbox_loss: 0.2104 - mrcnn_mask_loss: 0.2535Max memory usage during epoch 13: 512.328125 MiB
# 150/150 [==============================] - 513s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7910 - rpn_class_loss: 0.0117 - rpn_bbox_loss: 0.2220 - mrcnn_class_loss: 0.0935 - mrcnn_bbox_loss: 0.2104 - mrcnn_mask_loss: 0.2535 - val_loss: 0.8353 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.2164 - val_mrcnn_class_loss: 0.1014 - val_mrcnn_bbox_loss: 0.2472 - val_mrcnn_mask_loss: 0.2423 - memory_usage: 512.3281
# Epoch 14/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.7510 - rpn_class_loss: 0.0104 - rpn_bbox_loss: 0.2119 - mrcnn_class_loss: 0.0904 - mrcnn_bbox_loss: 0.1956 - mrcnn_mask_loss: 0.2427Max memory usage during epoch 14: 513.515625 MiB
# 150/150 [==============================] - 526s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7510 - rpn_class_loss: 0.0104 - rpn_bbox_loss: 0.2119 - mrcnn_class_loss: 0.0904 - mrcnn_bbox_loss: 0.1956 - mrcnn_mask_loss: 0.2427 - val_loss: 0.8390 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.2401 - val_mrcnn_class_loss: 0.0946 - val_mrcnn_bbox_loss: 0.2412 - val_mrcnn_mask_loss: 0.2365 - memory_usage: 513.5156
# Epoch 15/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.7443 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.2156 - mrcnn_class_loss: 0.0847 - mrcnn_bbox_loss: 0.1977 - mrcnn_mask_loss: 0.2348Max memory usage during epoch 15: 519.48828125 MiB
# 150/150 [==============================] - 520s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7443 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.2156 - mrcnn_class_loss: 0.0847 - mrcnn_bbox_loss: 0.1977 - mrcnn_mask_loss: 0.2348 - val_loss: 0.9612 - val_rpn_class_loss: 0.0152 - val_rpn_bbox_loss: 0.3513 - val_mrcnn_class_loss: 0.0712 - val_mrcnn_bbox_loss: 0.2413 - val_mrcnn_mask_loss: 0.2634 - memory_usage: 519.4883
# Epoch 16/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.7533 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 0.2189 - mrcnn_class_loss: 0.0912 - mrcnn_bbox_loss: 0.1918 - mrcnn_mask_loss: 0.2400Max memory usage during epoch 16: 521.87890625 MiB
# 150/150 [==============================] - 511s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7533 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 0.2189 - mrcnn_class_loss: 0.0912 - mrcnn_bbox_loss: 0.1918 - mrcnn_mask_loss: 0.2400 - val_loss: 1.0081 - val_rpn_class_loss: 0.0179 - val_rpn_bbox_loss: 0.4039 - val_mrcnn_class_loss: 0.0845 - val_mrcnn_bbox_loss: 0.2419 - val_mrcnn_mask_loss: 0.2402 - memory_usage: 521.8789
# Epoch 17/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.7214 - rpn_class_loss: 0.0118 - rpn_bbox_loss: 0.2014 - mrcnn_class_loss: 0.0840 - mrcnn_bbox_loss: 0.1817 - mrcnn_mask_loss: 0.2426Max memory usage during epoch 17: 524.80078125 MiB
# 150/150 [==============================] - 515s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7214 - rpn_class_loss: 0.0118 - rpn_bbox_loss: 0.2014 - mrcnn_class_loss: 0.0840 - mrcnn_bbox_loss: 0.1817 - mrcnn_mask_loss: 0.2426 - val_loss: 0.8543 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.2479 - val_mrcnn_class_loss: 0.0925 - val_mrcnn_bbox_loss: 0.2426 - val_mrcnn_mask_loss: 0.2445 - memory_usage: 524.8008
# Epoch 18/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.6696 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.1868 - mrcnn_class_loss: 0.0719 - mrcnn_bbox_loss: 0.1741 - mrcnn_mask_loss: 0.2272Max memory usage during epoch 18: 465.015625 MiB
# 150/150 [==============================] - 543s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6696 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.1868 - mrcnn_class_loss: 0.0719 - mrcnn_bbox_loss: 0.1741 - mrcnn_mask_loss: 0.2272 - val_loss: 0.8803 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.2938 - val_mrcnn_class_loss: 0.0681 - val_mrcnn_bbox_loss: 0.2352 - val_mrcnn_mask_loss: 0.2588 - memory_usage: 465.0156
# Epoch 19/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.7219 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.2163 - mrcnn_class_loss: 0.0747 - mrcnn_bbox_loss: 0.1814 - mrcnn_mask_loss: 0.2396Max memory usage during epoch 19: 531.12109375 MiB
# 150/150 [==============================] - 520s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7219 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.2163 - mrcnn_class_loss: 0.0747 - mrcnn_bbox_loss: 0.1814 - mrcnn_mask_loss: 0.2396 - val_loss: 0.7973 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.2522 - val_mrcnn_class_loss: 0.0586 - val_mrcnn_bbox_loss: 0.2463 - val_mrcnn_mask_loss: 0.2151 - memory_usage: 531.1211
# Epoch 20/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6868 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.1974 - mrcnn_class_loss: 0.0700 - mrcnn_bbox_loss: 0.1777 - mrcnn_mask_loss: 0.2322Max memory usage during epoch 20: 535.15234375 MiB
# 150/150 [==============================] - 533s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6868 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.1974 - mrcnn_class_loss: 0.0700 - mrcnn_bbox_loss: 0.1777 - mrcnn_mask_loss: 0.2322 - val_loss: 1.0141 - val_rpn_class_loss: 0.0193 - val_rpn_bbox_loss: 0.4267 - val_mrcnn_class_loss: 0.0656 - val_mrcnn_bbox_loss: 0.2418 - val_mrcnn_mask_loss: 0.2408 - memory_usage: 535.1523
# Epoch 21/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.7118 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.2067 - mrcnn_class_loss: 0.0818 - mrcnn_bbox_loss: 0.1754 - mrcnn_mask_loss: 0.2370Max memory usage during epoch 21: 533.9765625 MiB
# 150/150 [==============================] - 549s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.7118 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.2067 - mrcnn_class_loss: 0.0818 - mrcnn_bbox_loss: 0.1754 - mrcnn_mask_loss: 0.2370 - val_loss: 0.7741 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.2586 - val_mrcnn_class_loss: 0.0562 - val_mrcnn_bbox_loss: 0.2106 - val_mrcnn_mask_loss: 0.2246 - memory_usage: 533.9766
# Epoch 22/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6528 - rpn_class_loss: 0.0095 - rpn_bbox_loss: 0.1884 - mrcnn_class_loss: 0.0666 - mrcnn_bbox_loss: 0.1609 - mrcnn_mask_loss: 0.2274Max memory usage during epoch 22: 537.4921875 MiB
# 150/150 [==============================] - 521s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6528 - rpn_class_loss: 0.0095 - rpn_bbox_loss: 0.1884 - mrcnn_class_loss: 0.0666 - mrcnn_bbox_loss: 0.1609 - mrcnn_mask_loss: 0.2274 - val_loss: 1.0105 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.3536 - val_mrcnn_class_loss: 0.0759 - val_mrcnn_bbox_loss: 0.2627 - val_mrcnn_mask_loss: 0.2885 - memory_usage: 537.4922
# Epoch 23/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6597 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.1825 - mrcnn_class_loss: 0.0678 - mrcnn_bbox_loss: 0.1656 - mrcnn_mask_loss: 0.2332Max memory usage during epoch 23: 538.7109375 MiB
# 150/150 [==============================] - 509s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6597 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.1825 - mrcnn_class_loss: 0.0678 - mrcnn_bbox_loss: 0.1656 - mrcnn_mask_loss: 0.2332 - val_loss: 0.8324 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.2813 - val_mrcnn_class_loss: 0.0690 - val_mrcnn_bbox_loss: 0.2450 - val_mrcnn_mask_loss: 0.2135 - memory_usage: 538.7109
# Epoch 24/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6779 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.2072 - mrcnn_class_loss: 0.0711 - mrcnn_bbox_loss: 0.1667 - mrcnn_mask_loss: 0.2223Max memory usage during epoch 24: 541.87109375 MiB
# 150/150 [==============================] - 520s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6779 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.2072 - mrcnn_class_loss: 0.0711 - mrcnn_bbox_loss: 0.1667 - mrcnn_mask_loss: 0.2223 - val_loss: 0.9490 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.3578 - val_mrcnn_class_loss: 0.0527 - val_mrcnn_bbox_loss: 0.2585 - val_mrcnn_mask_loss: 0.2486 - memory_usage: 541.8711
# Epoch 25/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6285 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.1755 - mrcnn_class_loss: 0.0635 - mrcnn_bbox_loss: 0.1568 - mrcnn_mask_loss: 0.2231Max memory usage during epoch 25: 481.16015625 MiB
# 150/150 [==============================] - 533s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6285 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.1755 - mrcnn_class_loss: 0.0635 - mrcnn_bbox_loss: 0.1568 - mrcnn_mask_loss: 0.2231 - val_loss: 0.9510 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.3534 - val_mrcnn_class_loss: 0.0558 - val_mrcnn_bbox_loss: 0.2536 - val_mrcnn_mask_loss: 0.2583 - memory_usage: 481.1602
# Epoch 26/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6679 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.1973 - mrcnn_class_loss: 0.0730 - mrcnn_bbox_loss: 0.1595 - mrcnn_mask_loss: 0.2274Max memory usage during epoch 26: 541.9765625 MiB
# 150/150 [==============================] - 536s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6679 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.1973 - mrcnn_class_loss: 0.0730 - mrcnn_bbox_loss: 0.1595 - mrcnn_mask_loss: 0.2274 - val_loss: 0.8890 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.3168 - val_mrcnn_class_loss: 0.0762 - val_mrcnn_bbox_loss: 0.2237 - val_mrcnn_mask_loss: 0.2430 - memory_usage: 541.9766
# Epoch 27/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6223 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.1666 - mrcnn_class_loss: 0.0656 - mrcnn_bbox_loss: 0.1560 - mrcnn_mask_loss: 0.2242Max memory usage during epoch 27: 543.43359375 MiB
# 150/150 [==============================] - 525s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6223 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.1666 - mrcnn_class_loss: 0.0656 - mrcnn_bbox_loss: 0.1560 - mrcnn_mask_loss: 0.2242 - val_loss: 1.0551 - val_rpn_class_loss: 0.0155 - val_rpn_bbox_loss: 0.3623 - val_mrcnn_class_loss: 0.0757 - val_mrcnn_bbox_loss: 0.2693 - val_mrcnn_mask_loss: 0.3116 - memory_usage: 543.4336
# Epoch 28/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6392 - rpn_class_loss: 0.0098 - rpn_bbox_loss: 0.1744 - mrcnn_class_loss: 0.0622 - mrcnn_bbox_loss: 0.1592 - mrcnn_mask_loss: 0.2336Max memory usage during epoch 28: 546.3046875 MiB
# 150/150 [==============================] - 526s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6392 - rpn_class_loss: 0.0098 - rpn_bbox_loss: 0.1744 - mrcnn_class_loss: 0.0622 - mrcnn_bbox_loss: 0.1592 - mrcnn_mask_loss: 0.2336 - val_loss: 1.0612 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.4053 - val_mrcnn_class_loss: 0.0750 - val_mrcnn_bbox_loss: 0.2784 - val_mrcnn_mask_loss: 0.2667 - memory_usage: 546.3047
# Epoch 29/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6412 - rpn_class_loss: 0.0100 - rpn_bbox_loss: 0.1767 - mrcnn_class_loss: 0.0683 - mrcnn_bbox_loss: 0.1567 - mrcnn_mask_loss: 0.2294Max memory usage during epoch 29: 548.51171875 MiB
# 150/150 [==============================] - 529s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6412 - rpn_class_loss: 0.0100 - rpn_bbox_loss: 0.1767 - mrcnn_class_loss: 0.0683 - mrcnn_bbox_loss: 0.1567 - mrcnn_mask_loss: 0.2294 - val_loss: 0.9488 - val_rpn_class_loss: 0.0151 - val_rpn_bbox_loss: 0.3341 - val_mrcnn_class_loss: 0.0597 - val_mrcnn_bbox_loss: 0.2611 - val_mrcnn_mask_loss: 0.2603 - memory_usage: 548.5117
# Epoch 30/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6043 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1771 - mrcnn_class_loss: 0.0589 - mrcnn_bbox_loss: 0.1445 - mrcnn_mask_loss: 0.2161Max memory usage during epoch 30: 551.8359375 MiB
# 150/150 [==============================] - 517s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6043 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1771 - mrcnn_class_loss: 0.0589 - mrcnn_bbox_loss: 0.1445 - mrcnn_mask_loss: 0.2161 - val_loss: 0.7928 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.2298 - val_mrcnn_class_loss: 0.0616 - val_mrcnn_bbox_loss: 0.2348 - val_mrcnn_mask_loss: 0.2429 - memory_usage: 551.8359
# Epoch 31/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6074 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1720 - mrcnn_class_loss: 0.0584 - mrcnn_bbox_loss: 0.1473 - mrcnn_mask_loss: 0.2223Max memory usage during epoch 31: 549.66796875 MiB
# 150/150 [==============================] - 521s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6074 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1720 - mrcnn_class_loss: 0.0584 - mrcnn_bbox_loss: 0.1473 - mrcnn_mask_loss: 0.2223 - val_loss: 0.9738 - val_rpn_class_loss: 0.0121 - val_rpn_bbox_loss: 0.3793 - val_mrcnn_class_loss: 0.0905 - val_mrcnn_bbox_loss: 0.2311 - val_mrcnn_mask_loss: 0.2417 - memory_usage: 549.6680
# Epoch 32/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.6405 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.1869 - mrcnn_class_loss: 0.0642 - mrcnn_bbox_loss: 0.1514 - mrcnn_mask_loss: 0.2282Max memory usage during epoch 32: 552.1328125 MiB
# 150/150 [==============================] - 546s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6405 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.1869 - mrcnn_class_loss: 0.0642 - mrcnn_bbox_loss: 0.1514 - mrcnn_mask_loss: 0.2282 - val_loss: 0.8938 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.3878 - val_mrcnn_class_loss: 0.0613 - val_mrcnn_bbox_loss: 0.1936 - val_mrcnn_mask_loss: 0.2224 - memory_usage: 552.1328
# Epoch 33/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.6065 - rpn_class_loss: 0.0093 - rpn_bbox_loss: 0.1807 - mrcnn_class_loss: 0.0568 - mrcnn_bbox_loss: 0.1452 - mrcnn_mask_loss: 0.2146Max memory usage during epoch 33: 554.4765625 MiB
# 150/150 [==============================] - 525s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.6065 - rpn_class_loss: 0.0093 - rpn_bbox_loss: 0.1807 - mrcnn_class_loss: 0.0568 - mrcnn_bbox_loss: 0.1452 - mrcnn_mask_loss: 0.2146 - val_loss: 1.0984 - val_rpn_class_loss: 0.0163 - val_rpn_bbox_loss: 0.4757 - val_mrcnn_class_loss: 0.0739 - val_mrcnn_bbox_loss: 0.2555 - val_mrcnn_mask_loss: 0.2555 - memory_usage: 554.4766
# Epoch 34/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5825 - rpn_class_loss: 0.0087 - rpn_bbox_loss: 0.1676 - mrcnn_class_loss: 0.0580 - mrcnn_bbox_loss: 0.1367 - mrcnn_mask_loss: 0.2115Max memory usage during epoch 34: 554.1875 MiB
# 150/150 [==============================] - 511s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5825 - rpn_class_loss: 0.0087 - rpn_bbox_loss: 0.1676 - mrcnn_class_loss: 0.0580 - mrcnn_bbox_loss: 0.1367 - mrcnn_mask_loss: 0.2115 - val_loss: 0.8229 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.3111 - val_mrcnn_class_loss: 0.0527 - val_mrcnn_bbox_loss: 0.1964 - val_mrcnn_mask_loss: 0.2369 - memory_usage: 554.1875
# Epoch 35/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.5807 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.1650 - mrcnn_class_loss: 0.0543 - mrcnn_bbox_loss: 0.1358 - mrcnn_mask_loss: 0.2178Max memory usage during epoch 35: 556.94921875 MiB
# 150/150 [==============================] - 554s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5807 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.1650 - mrcnn_class_loss: 0.0543 - mrcnn_bbox_loss: 0.1358 - mrcnn_mask_loss: 0.2178 - val_loss: 0.8505 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.3211 - val_mrcnn_class_loss: 0.0561 - val_mrcnn_bbox_loss: 0.2271 - val_mrcnn_mask_loss: 0.2202 - memory_usage: 556.9492
# Epoch 36/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.5683 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.1642 - mrcnn_class_loss: 0.0539 - mrcnn_bbox_loss: 0.1289 - mrcnn_mask_loss: 0.2130Max memory usage during epoch 36: 558.1484375 MiB
# 150/150 [==============================] - 551s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5683 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.1642 - mrcnn_class_loss: 0.0539 - mrcnn_bbox_loss: 0.1289 - mrcnn_mask_loss: 0.2130 - val_loss: 0.9003 - val_rpn_class_loss: 0.0165 - val_rpn_bbox_loss: 0.4187 - val_mrcnn_class_loss: 0.0541 - val_mrcnn_bbox_loss: 0.1940 - val_mrcnn_mask_loss: 0.1993 - memory_usage: 558.1484
# Epoch 37/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5692 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1584 - mrcnn_class_loss: 0.0533 - mrcnn_bbox_loss: 0.1349 - mrcnn_mask_loss: 0.2149Max memory usage during epoch 37: 543.3046875 MiB
# 150/150 [==============================] - 527s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5692 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1584 - mrcnn_class_loss: 0.0533 - mrcnn_bbox_loss: 0.1349 - mrcnn_mask_loss: 0.2149 - val_loss: 0.8589 - val_rpn_class_loss: 0.0136 - val_rpn_bbox_loss: 0.3263 - val_mrcnn_class_loss: 0.0677 - val_mrcnn_bbox_loss: 0.2200 - val_mrcnn_mask_loss: 0.2146 - memory_usage: 543.3047
# Epoch 38/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5469 - rpn_class_loss: 0.0086 - rpn_bbox_loss: 0.1500 - mrcnn_class_loss: 0.0572 - mrcnn_bbox_loss: 0.1246 - mrcnn_mask_loss: 0.2064Max memory usage during epoch 38: 558.2109375 MiB
# 150/150 [==============================] - 516s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5469 - rpn_class_loss: 0.0086 - rpn_bbox_loss: 0.1500 - mrcnn_class_loss: 0.0572 - mrcnn_bbox_loss: 0.1246 - mrcnn_mask_loss: 0.2064 - val_loss: 0.8738 - val_rpn_class_loss: 0.0122 - val_rpn_bbox_loss: 0.2860 - val_mrcnn_class_loss: 0.0980 - val_mrcnn_bbox_loss: 0.2253 - val_mrcnn_mask_loss: 0.2352 - memory_usage: 558.2109
# Epoch 39/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5495 - rpn_class_loss: 0.0090 - rpn_bbox_loss: 0.1537 - mrcnn_class_loss: 0.0534 - mrcnn_bbox_loss: 0.1255 - mrcnn_mask_loss: 0.2080Max memory usage during epoch 39: 557.79296875 MiB
# 150/150 [==============================] - 519s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5495 - rpn_class_loss: 0.0090 - rpn_bbox_loss: 0.1537 - mrcnn_class_loss: 0.0534 - mrcnn_bbox_loss: 0.1255 - mrcnn_mask_loss: 0.2080 - val_loss: 0.8691 - val_rpn_class_loss: 0.0109 - val_rpn_bbox_loss: 0.2959 - val_mrcnn_class_loss: 0.0737 - val_mrcnn_bbox_loss: 0.2251 - val_mrcnn_mask_loss: 0.2465 - memory_usage: 557.7930
# Epoch 40/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5520 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.1568 - mrcnn_class_loss: 0.0579 - mrcnn_bbox_loss: 0.1233 - mrcnn_mask_loss: 0.2059Max memory usage during epoch 40: 559.7109375 MiB
# 150/150 [==============================] - 532s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5520 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.1568 - mrcnn_class_loss: 0.0579 - mrcnn_bbox_loss: 0.1233 - mrcnn_mask_loss: 0.2059 - val_loss: 0.8773 - val_rpn_class_loss: 0.0109 - val_rpn_bbox_loss: 0.3229 - val_mrcnn_class_loss: 0.0652 - val_mrcnn_bbox_loss: 0.2178 - val_mrcnn_mask_loss: 0.2433 - memory_usage: 559.7109
# Epoch 41/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5609 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.1645 - mrcnn_class_loss: 0.0529 - mrcnn_bbox_loss: 0.1266 - mrcnn_mask_loss: 0.2085Max memory usage during epoch 41: 559.09765625 MiB
# 150/150 [==============================] - 526s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5609 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.1645 - mrcnn_class_loss: 0.0529 - mrcnn_bbox_loss: 0.1266 - mrcnn_mask_loss: 0.2085 - val_loss: 0.9337 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.3292 - val_mrcnn_class_loss: 0.0858 - val_mrcnn_bbox_loss: 0.2498 - val_mrcnn_mask_loss: 0.2398 - memory_usage: 559.0977
# Epoch 42/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5366 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.1501 - mrcnn_class_loss: 0.0499 - mrcnn_bbox_loss: 0.1246 - mrcnn_mask_loss: 0.2046Max memory usage during epoch 42: 560.64453125 MiB
# 150/150 [==============================] - 530s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5366 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.1501 - mrcnn_class_loss: 0.0499 - mrcnn_bbox_loss: 0.1246 - mrcnn_mask_loss: 0.2046 - val_loss: 0.9197 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.3949 - val_mrcnn_class_loss: 0.0593 - val_mrcnn_bbox_loss: 0.2050 - val_mrcnn_mask_loss: 0.2300 - memory_usage: 560.6445
# Epoch 43/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5338 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.1486 - mrcnn_class_loss: 0.0529 - mrcnn_bbox_loss: 0.1226 - mrcnn_mask_loss: 0.2012Max memory usage during epoch 43: 525.91796875 MiB
# 150/150 [==============================] - 523s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5338 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.1486 - mrcnn_class_loss: 0.0529 - mrcnn_bbox_loss: 0.1226 - mrcnn_mask_loss: 0.2012 - val_loss: 0.8616 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.3054 - val_mrcnn_class_loss: 0.0614 - val_mrcnn_bbox_loss: 0.2343 - val_mrcnn_mask_loss: 0.2344 - memory_usage: 525.9180
# Epoch 44/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5502 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.1640 - mrcnn_class_loss: 0.0484 - mrcnn_bbox_loss: 0.1221 - mrcnn_mask_loss: 0.2078Max memory usage during epoch 44: 525.640625 MiB
# 150/150 [==============================] - 524s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5502 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.1640 - mrcnn_class_loss: 0.0484 - mrcnn_bbox_loss: 0.1221 - mrcnn_mask_loss: 0.2078 - val_loss: 0.8445 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.2909 - val_mrcnn_class_loss: 0.0619 - val_mrcnn_bbox_loss: 0.2269 - val_mrcnn_mask_loss: 0.2398 - memory_usage: 525.6406
# Epoch 45/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5125 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.1418 - mrcnn_class_loss: 0.0503 - mrcnn_bbox_loss: 0.1144 - mrcnn_mask_loss: 0.1980Max memory usage during epoch 45: 528.5234375 MiB
# 150/150 [==============================] - 525s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5125 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.1418 - mrcnn_class_loss: 0.0503 - mrcnn_bbox_loss: 0.1144 - mrcnn_mask_loss: 0.1980 - val_loss: 0.7945 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.2540 - val_mrcnn_class_loss: 0.0525 - val_mrcnn_bbox_loss: 0.2287 - val_mrcnn_mask_loss: 0.2339 - memory_usage: 528.5234
# Epoch 46/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5193 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1413 - mrcnn_class_loss: 0.0481 - mrcnn_bbox_loss: 0.1172 - mrcnn_mask_loss: 0.2051Max memory usage during epoch 46: 528.171875 MiB
# 150/150 [==============================] - 529s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5193 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1413 - mrcnn_class_loss: 0.0481 - mrcnn_bbox_loss: 0.1172 - mrcnn_mask_loss: 0.2051 - val_loss: 0.9525 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.3456 - val_mrcnn_class_loss: 0.0615 - val_mrcnn_bbox_loss: 0.2480 - val_mrcnn_mask_loss: 0.2688 - memory_usage: 528.1719
# Epoch 47/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4814 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.1294 - mrcnn_class_loss: 0.0440 - mrcnn_bbox_loss: 0.1059 - mrcnn_mask_loss: 0.1952Max memory usage during epoch 47: 530.6015625 MiB
# 150/150 [==============================] - 520s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4814 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.1294 - mrcnn_class_loss: 0.0440 - mrcnn_bbox_loss: 0.1059 - mrcnn_mask_loss: 0.1952 - val_loss: 0.8079 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.3066 - val_mrcnn_class_loss: 0.0497 - val_mrcnn_bbox_loss: 0.2087 - val_mrcnn_mask_loss: 0.2186 - memory_usage: 530.6016
# Epoch 48/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4927 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.1371 - mrcnn_class_loss: 0.0473 - mrcnn_bbox_loss: 0.1086 - mrcnn_mask_loss: 0.1921Max memory usage during epoch 48: 534.3984375 MiB
# 150/150 [==============================] - 523s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4927 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.1371 - mrcnn_class_loss: 0.0473 - mrcnn_bbox_loss: 0.1086 - mrcnn_mask_loss: 0.1921 - val_loss: 0.9782 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.3245 - val_mrcnn_class_loss: 0.0690 - val_mrcnn_bbox_loss: 0.2768 - val_mrcnn_mask_loss: 0.2774 - memory_usage: 534.3984
# Epoch 49/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.5147 - rpn_class_loss: 0.0090 - rpn_bbox_loss: 0.1524 - mrcnn_class_loss: 0.0480 - mrcnn_bbox_loss: 0.1071 - mrcnn_mask_loss: 0.1982Max memory usage during epoch 49: 464.28125 MiB
# 150/150 [==============================] - 507s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.5147 - rpn_class_loss: 0.0090 - rpn_bbox_loss: 0.1524 - mrcnn_class_loss: 0.0480 - mrcnn_bbox_loss: 0.1071 - mrcnn_mask_loss: 0.1982 - val_loss: 1.0796 - val_rpn_class_loss: 0.0152 - val_rpn_bbox_loss: 0.4467 - val_mrcnn_class_loss: 0.0684 - val_mrcnn_bbox_loss: 0.2540 - val_mrcnn_mask_loss: 0.2743 - memory_usage: 464.2812
# Epoch 50/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.4953 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1347 - mrcnn_class_loss: 0.0469 - mrcnn_bbox_loss: 0.1073 - mrcnn_mask_loss: 0.1987Max memory usage during epoch 50: 534.5859375 MiB
# 150/150 [==============================] - 553s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4953 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1347 - mrcnn_class_loss: 0.0469 - mrcnn_bbox_loss: 0.1073 - mrcnn_mask_loss: 0.1987 - val_loss: 1.1013 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.4230 - val_mrcnn_class_loss: 0.0797 - val_mrcnn_bbox_loss: 0.2654 - val_mrcnn_mask_loss: 0.2987 - memory_usage: 534.5859
# Epoch 51/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4911 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1281 - mrcnn_class_loss: 0.0438 - mrcnn_bbox_loss: 0.1126 - mrcnn_mask_loss: 0.1997Max memory usage during epoch 51: 536.90234375 MiB
# 150/150 [==============================] - 526s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4911 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1281 - mrcnn_class_loss: 0.0438 - mrcnn_bbox_loss: 0.1126 - mrcnn_mask_loss: 0.1997 - val_loss: 0.8789 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.3206 - val_mrcnn_class_loss: 0.0558 - val_mrcnn_bbox_loss: 0.2315 - val_mrcnn_mask_loss: 0.2453 - memory_usage: 536.9023
# Epoch 52/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4953 - rpn_class_loss: 0.0086 - rpn_bbox_loss: 0.1405 - mrcnn_class_loss: 0.0487 - mrcnn_bbox_loss: 0.1080 - mrcnn_mask_loss: 0.1895Max memory usage during epoch 52: 511.30078125 MiB
# 150/150 [==============================] - 527s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4953 - rpn_class_loss: 0.0086 - rpn_bbox_loss: 0.1405 - mrcnn_class_loss: 0.0487 - mrcnn_bbox_loss: 0.1080 - mrcnn_mask_loss: 0.1895 - val_loss: 0.8808 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.3714 - val_mrcnn_class_loss: 0.0473 - val_mrcnn_bbox_loss: 0.2064 - val_mrcnn_mask_loss: 0.2280 - memory_usage: 511.3008
# Epoch 53/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4862 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1239 - mrcnn_class_loss: 0.0458 - mrcnn_bbox_loss: 0.1124 - mrcnn_mask_loss: 0.1965Max memory usage during epoch 53: 513.13671875 MiB
# 150/150 [==============================] - 534s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4862 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.1239 - mrcnn_class_loss: 0.0458 - mrcnn_bbox_loss: 0.1124 - mrcnn_mask_loss: 0.1965 - val_loss: 0.8484 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.3345 - val_mrcnn_class_loss: 0.0634 - val_mrcnn_bbox_loss: 0.2027 - val_mrcnn_mask_loss: 0.2223 - memory_usage: 513.1367
# Epoch 54/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4872 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1250 - mrcnn_class_loss: 0.0546 - mrcnn_bbox_loss: 0.1042 - mrcnn_mask_loss: 0.1959Max memory usage during epoch 54: 514.4296875 MiB
# 150/150 [==============================] - 524s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4872 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1250 - mrcnn_class_loss: 0.0546 - mrcnn_bbox_loss: 0.1042 - mrcnn_mask_loss: 0.1959 - val_loss: 1.0025 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.4571 - val_mrcnn_class_loss: 0.0517 - val_mrcnn_bbox_loss: 0.2292 - val_mrcnn_mask_loss: 0.2330 - memory_usage: 514.4297
# Epoch 55/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4862 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.1284 - mrcnn_class_loss: 0.0458 - mrcnn_bbox_loss: 0.1070 - mrcnn_mask_loss: 0.1979Max memory usage during epoch 55: 517.17578125 MiB
# 150/150 [==============================] - 536s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4862 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.1284 - mrcnn_class_loss: 0.0458 - mrcnn_bbox_loss: 0.1070 - mrcnn_mask_loss: 0.1979 - val_loss: 1.0035 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.4528 - val_mrcnn_class_loss: 0.0557 - val_mrcnn_bbox_loss: 0.2196 - val_mrcnn_mask_loss: 0.2438 - memory_usage: 517.1758
# Epoch 56/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4564 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.1212 - mrcnn_class_loss: 0.0399 - mrcnn_bbox_loss: 0.0999 - mrcnn_mask_loss: 0.1888Max memory usage during epoch 56: 508.15625 MiB
# 150/150 [==============================] - 508s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4564 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.1212 - mrcnn_class_loss: 0.0399 - mrcnn_bbox_loss: 0.0999 - mrcnn_mask_loss: 0.1888 - val_loss: 0.8916 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.3668 - val_mrcnn_class_loss: 0.0537 - val_mrcnn_bbox_loss: 0.2086 - val_mrcnn_mask_loss: 0.2321 - memory_usage: 508.1562
# Epoch 57/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4823 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1208 - mrcnn_class_loss: 0.0452 - mrcnn_bbox_loss: 0.1100 - mrcnn_mask_loss: 0.1989Max memory usage during epoch 57: 510.41796875 MiB
# 150/150 [==============================] - 505s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4823 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1208 - mrcnn_class_loss: 0.0452 - mrcnn_bbox_loss: 0.1100 - mrcnn_mask_loss: 0.1989 - val_loss: 1.0128 - val_rpn_class_loss: 0.0160 - val_rpn_bbox_loss: 0.4430 - val_mrcnn_class_loss: 0.0612 - val_mrcnn_bbox_loss: 0.2248 - val_mrcnn_mask_loss: 0.2479 - memory_usage: 510.4180
# Epoch 58/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4814 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1223 - mrcnn_class_loss: 0.0469 - mrcnn_bbox_loss: 0.1055 - mrcnn_mask_loss: 0.1997Max memory usage during epoch 58: 511.5390625 MiB
# 150/150 [==============================] - 504s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4814 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1223 - mrcnn_class_loss: 0.0469 - mrcnn_bbox_loss: 0.1055 - mrcnn_mask_loss: 0.1997 - val_loss: 0.8319 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.2859 - val_mrcnn_class_loss: 0.0605 - val_mrcnn_bbox_loss: 0.2280 - val_mrcnn_mask_loss: 0.2309 - memory_usage: 511.5391
# Epoch 59/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4862 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.1374 - mrcnn_class_loss: 0.0472 - mrcnn_bbox_loss: 0.1003 - mrcnn_mask_loss: 0.1934Max memory usage during epoch 59: 512.80078125 MiB
# 150/150 [==============================] - 505s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4862 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.1374 - mrcnn_class_loss: 0.0472 - mrcnn_bbox_loss: 0.1003 - mrcnn_mask_loss: 0.1934 - val_loss: 0.8385 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.2839 - val_mrcnn_class_loss: 0.0542 - val_mrcnn_bbox_loss: 0.2332 - val_mrcnn_mask_loss: 0.2408 - memory_usage: 512.8008
# Epoch 60/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4854 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1366 - mrcnn_class_loss: 0.0426 - mrcnn_bbox_loss: 0.1028 - mrcnn_mask_loss: 0.1960Max memory usage during epoch 60: 513.9453125 MiB
# 150/150 [==============================] - 505s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4854 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1366 - mrcnn_class_loss: 0.0426 - mrcnn_bbox_loss: 0.1028 - mrcnn_mask_loss: 0.1960 - val_loss: 0.8115 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.2588 - val_mrcnn_class_loss: 0.0580 - val_mrcnn_bbox_loss: 0.2169 - val_mrcnn_mask_loss: 0.2542 - memory_usage: 513.9453
# Epoch 61/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4286 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1078 - mrcnn_class_loss: 0.0387 - mrcnn_bbox_loss: 0.0953 - mrcnn_mask_loss: 0.1799Max memory usage during epoch 61: 514.3671875 MiB
# 150/150 [==============================] - 514s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4286 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1078 - mrcnn_class_loss: 0.0387 - mrcnn_bbox_loss: 0.0953 - mrcnn_mask_loss: 0.1799 - val_loss: 0.8784 - val_rpn_class_loss: 0.0132 - val_rpn_bbox_loss: 0.3715 - val_mrcnn_class_loss: 0.0547 - val_mrcnn_bbox_loss: 0.2117 - val_mrcnn_mask_loss: 0.2101 - memory_usage: 514.3672
# Epoch 62/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4380 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1154 - mrcnn_class_loss: 0.0396 - mrcnn_bbox_loss: 0.0899 - mrcnn_mask_loss: 0.1867Max memory usage during epoch 62: 514.66015625 MiB
# 150/150 [==============================] - 509s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4380 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1154 - mrcnn_class_loss: 0.0396 - mrcnn_bbox_loss: 0.0899 - mrcnn_mask_loss: 0.1867 - val_loss: 0.7955 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.2986 - val_mrcnn_class_loss: 0.0436 - val_mrcnn_bbox_loss: 0.2030 - val_mrcnn_mask_loss: 0.2269 - memory_usage: 514.6602
# Epoch 63/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4464 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.1209 - mrcnn_class_loss: 0.0396 - mrcnn_bbox_loss: 0.0926 - mrcnn_mask_loss: 0.1878Max memory usage during epoch 63: 445.53125 MiB
# 150/150 [==============================] - 517s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4464 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.1209 - mrcnn_class_loss: 0.0396 - mrcnn_bbox_loss: 0.0926 - mrcnn_mask_loss: 0.1878 - val_loss: 1.0075 - val_rpn_class_loss: 0.0165 - val_rpn_bbox_loss: 0.4357 - val_mrcnn_class_loss: 0.0527 - val_mrcnn_bbox_loss: 0.2307 - val_mrcnn_mask_loss: 0.2521 - memory_usage: 445.5312
# Epoch 64/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4598 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1281 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.0942 - mrcnn_mask_loss: 0.1884Max memory usage during epoch 64: 514.609375 MiB
# 150/150 [==============================] - 515s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4598 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.1281 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.0942 - mrcnn_mask_loss: 0.1884 - val_loss: 0.8560 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.3353 - val_mrcnn_class_loss: 0.0526 - val_mrcnn_bbox_loss: 0.2173 - val_mrcnn_mask_loss: 0.2229 - memory_usage: 514.6094
# Epoch 65/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4489 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.1141 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.0973 - mrcnn_mask_loss: 0.1888Max memory usage during epoch 65: 517.46875 MiB
# 150/150 [==============================] - 509s 3s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4489 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.1141 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.0973 - mrcnn_mask_loss: 0.1888 - val_loss: 0.9079 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.3540 - val_mrcnn_class_loss: 0.0578 - val_mrcnn_bbox_loss: 0.2246 - val_mrcnn_mask_loss: 0.2409 - memory_usage: 517.4688
# Epoch 66/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.4348 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.1055 - mrcnn_class_loss: 0.0390 - mrcnn_bbox_loss: 0.0942 - mrcnn_mask_loss: 0.1891Max memory usage during epoch 66: 523.84765625 MiB
# ...
# Epoch 79/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3966 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.0986 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.0807 - mrcnn_mask_loss: 0.1777Max memory usage during epoch 79: 426.69921875 MiB
# 150/150 [==============================] - 604s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3966 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.0986 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.0807 - mrcnn_mask_loss: 0.1777 - val_loss: 0.9070 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.3642 - val_mrcnn_class_loss: 0.0553 - val_mrcnn_bbox_loss: 0.2301 - val_mrcnn_mask_loss: 0.2300 - memory_usage: 426.6992
# Epoch 80/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.4032 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.1011 - mrcnn_class_loss: 0.0312 - mrcnn_bbox_loss: 0.0843 - mrcnn_mask_loss: 0.1806Max memory usage during epoch 80: 429.8359375 MiB
# 150/150 [==============================] - 591s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4032 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.1011 - mrcnn_class_loss: 0.0312 - mrcnn_bbox_loss: 0.0843 - mrcnn_mask_loss: 0.1806 - val_loss: 1.0324 - val_rpn_class_loss: 0.0157 - val_rpn_bbox_loss: 0.4553 - val_mrcnn_class_loss: 0.0712 - val_mrcnn_bbox_loss: 0.2272 - val_mrcnn_mask_loss: 0.2428 - memory_usage: 429.8359
# Epoch 81/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3917 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.0963 - mrcnn_class_loss: 0.0343 - mrcnn_bbox_loss: 0.0778 - mrcnn_mask_loss: 0.1768Max memory usage during epoch 81: 446.8828125 MiB
# 150/150 [==============================] - 566s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3917 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.0963 - mrcnn_class_loss: 0.0343 - mrcnn_bbox_loss: 0.0778 - mrcnn_mask_loss: 0.1768 - val_loss: 0.9317 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.3596 - val_mrcnn_class_loss: 0.0551 - val_mrcnn_bbox_loss: 0.2394 - val_mrcnn_mask_loss: 0.2480 - memory_usage: 446.8828
# Epoch 82/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3812 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.0950 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0748 - mrcnn_mask_loss: 0.1718Max memory usage during epoch 82: 460.06640625 MiB
# 150/150 [==============================] - 578s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3812 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.0950 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0748 - mrcnn_mask_loss: 0.1718 - val_loss: 0.8512 - val_rpn_class_loss: 0.0078 - val_rpn_bbox_loss: 0.2953 - val_mrcnn_class_loss: 0.0539 - val_mrcnn_bbox_loss: 0.2229 - val_mrcnn_mask_loss: 0.2545 - memory_usage: 460.0664
# Epoch 83/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.4230 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.1073 - mrcnn_class_loss: 0.0377 - mrcnn_bbox_loss: 0.0884 - mrcnn_mask_loss: 0.1833Max memory usage during epoch 83: 457.69921875 MiB
# 150/150 [==============================] - 546s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4230 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.1073 - mrcnn_class_loss: 0.0377 - mrcnn_bbox_loss: 0.0884 - mrcnn_mask_loss: 0.1833 - val_loss: 0.9582 - val_rpn_class_loss: 0.0148 - val_rpn_bbox_loss: 0.4484 - val_mrcnn_class_loss: 0.0481 - val_mrcnn_bbox_loss: 0.1942 - val_mrcnn_mask_loss: 0.2340 - memory_usage: 457.6992
# Epoch 84/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3941 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0982 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0793 - mrcnn_mask_loss: 0.1775Max memory usage during epoch 84: 465.8828125 MiB
# 150/150 [==============================] - 570s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3941 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0982 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0793 - mrcnn_mask_loss: 0.1775 - val_loss: 0.9263 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.3641 - val_mrcnn_class_loss: 0.0550 - val_mrcnn_bbox_loss: 0.2335 - val_mrcnn_mask_loss: 0.2443 - memory_usage: 465.8828
# Epoch 85/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3932 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.0971 - mrcnn_class_loss: 0.0363 - mrcnn_bbox_loss: 0.0755 - mrcnn_mask_loss: 0.1779Max memory usage during epoch 85: 483.7265625 MiB
# 150/150 [==============================] - 573s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3932 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.0971 - mrcnn_class_loss: 0.0363 - mrcnn_bbox_loss: 0.0755 - mrcnn_mask_loss: 0.1779 - val_loss: 0.8996 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.3552 - val_mrcnn_class_loss: 0.0496 - val_mrcnn_bbox_loss: 0.2192 - val_mrcnn_mask_loss: 0.2481 - memory_usage: 483.7266
# Epoch 86/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3733 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.0896 - mrcnn_class_loss: 0.0305 - mrcnn_bbox_loss: 0.0768 - mrcnn_mask_loss: 0.1712Max memory usage during epoch 86: 475.29296875 MiB
# 150/150 [==============================] - 591s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3733 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.0896 - mrcnn_class_loss: 0.0305 - mrcnn_bbox_loss: 0.0768 - mrcnn_mask_loss: 0.1712 - val_loss: 0.9425 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.3934 - val_mrcnn_class_loss: 0.0498 - val_mrcnn_bbox_loss: 0.2242 - val_mrcnn_mask_loss: 0.2454 - memory_usage: 475.2930
# Epoch 87/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3679 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.0885 - mrcnn_class_loss: 0.0300 - mrcnn_bbox_loss: 0.0752 - mrcnn_mask_loss: 0.1687Max memory usage during epoch 87: 483.66796875 MiB
# 150/150 [==============================] - 603s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3679 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.0885 - mrcnn_class_loss: 0.0300 - mrcnn_bbox_loss: 0.0752 - mrcnn_mask_loss: 0.1687 - val_loss: 0.8734 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.3116 - val_mrcnn_class_loss: 0.0624 - val_mrcnn_bbox_loss: 0.2432 - val_mrcnn_mask_loss: 0.2306 - memory_usage: 483.6680
# Epoch 88/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.4060 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1015 - mrcnn_class_loss: 0.0355 - mrcnn_bbox_loss: 0.0837 - mrcnn_mask_loss: 0.1784Max memory usage during epoch 88: 472.5703125 MiB
# 150/150 [==============================] - 611s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.4060 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1015 - mrcnn_class_loss: 0.0355 - mrcnn_bbox_loss: 0.0837 - mrcnn_mask_loss: 0.1784 - val_loss: 0.9348 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.3456 - val_mrcnn_class_loss: 0.0535 - val_mrcnn_bbox_loss: 0.2493 - val_mrcnn_mask_loss: 0.2551 - memory_usage: 472.5703
# Epoch 89/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3753 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0969 - mrcnn_class_loss: 0.0286 - mrcnn_bbox_loss: 0.0737 - mrcnn_mask_loss: 0.1704Max memory usage during epoch 89: 465.4140625 MiB
# 150/150 [==============================] - 609s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3753 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0969 - mrcnn_class_loss: 0.0286 - mrcnn_bbox_loss: 0.0737 - mrcnn_mask_loss: 0.1704 - val_loss: 1.0525 - val_rpn_class_loss: 0.0185 - val_rpn_bbox_loss: 0.4577 - val_mrcnn_class_loss: 0.0658 - val_mrcnn_bbox_loss: 0.2279 - val_mrcnn_mask_loss: 0.2619 - memory_usage: 465.4141
# Epoch 90/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3664 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0906 - mrcnn_class_loss: 0.0298 - mrcnn_bbox_loss: 0.0716 - mrcnn_mask_loss: 0.1687Max memory usage during epoch 90: 473.41796875 MiB
# 150/150 [==============================] - 614s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3664 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0906 - mrcnn_class_loss: 0.0298 - mrcnn_bbox_loss: 0.0716 - mrcnn_mask_loss: 0.1687 - val_loss: 0.8670 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.3498 - val_mrcnn_class_loss: 0.0535 - val_mrcnn_bbox_loss: 0.2010 - val_mrcnn_mask_loss: 0.2363 - memory_usage: 473.4180
# Epoch 91/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3763 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.0916 - mrcnn_class_loss: 0.0349 - mrcnn_bbox_loss: 0.0726 - mrcnn_mask_loss: 0.1714Max memory usage during epoch 91: 481.2265625 MiB
# 150/150 [==============================] - 608s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3763 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.0916 - mrcnn_class_loss: 0.0349 - mrcnn_bbox_loss: 0.0726 - mrcnn_mask_loss: 0.1714 - val_loss: 0.8437 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.3683 - val_mrcnn_class_loss: 0.0472 - val_mrcnn_bbox_loss: 0.1829 - val_mrcnn_mask_loss: 0.2196 - memory_usage: 481.2266
# Epoch 92/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3552 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0827 - mrcnn_class_loss: 0.0311 - mrcnn_bbox_loss: 0.0706 - mrcnn_mask_loss: 0.1648Max memory usage during epoch 92: 476.46484375 MiB
# 150/150 [==============================] - 609s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3552 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0827 - mrcnn_class_loss: 0.0311 - mrcnn_bbox_loss: 0.0706 - mrcnn_mask_loss: 0.1648 - val_loss: 1.1852 - val_rpn_class_loss: 0.0218 - val_rpn_bbox_loss: 0.6718 - val_mrcnn_class_loss: 0.0482 - val_mrcnn_bbox_loss: 0.1873 - val_mrcnn_mask_loss: 0.2330 - memory_usage: 476.4648
# Epoch 93/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3497 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.0819 - mrcnn_class_loss: 0.0311 - mrcnn_bbox_loss: 0.0683 - mrcnn_mask_loss: 0.1630Max memory usage during epoch 93: 478.7265625 MiB
# 150/150 [==============================] - 618s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3497 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.0819 - mrcnn_class_loss: 0.0311 - mrcnn_bbox_loss: 0.0683 - mrcnn_mask_loss: 0.1630 - val_loss: 0.9216 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.2958 - val_mrcnn_class_loss: 0.0743 - val_mrcnn_bbox_loss: 0.2654 - val_mrcnn_mask_loss: 0.2583 - memory_usage: 478.7266
# Epoch 94/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3628 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0887 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0714 - mrcnn_mask_loss: 0.1639Max memory usage during epoch 94: 487.12109375 MiB
# 150/150 [==============================] - 615s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3628 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0887 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0714 - mrcnn_mask_loss: 0.1639 - val_loss: 1.1478 - val_rpn_class_loss: 0.0194 - val_rpn_bbox_loss: 0.4636 - val_mrcnn_class_loss: 0.0737 - val_mrcnn_bbox_loss: 0.2817 - val_mrcnn_mask_loss: 0.2869 - memory_usage: 487.1211
# Epoch 95/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3786 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.0924 - mrcnn_class_loss: 0.0344 - mrcnn_bbox_loss: 0.0750 - mrcnn_mask_loss: 0.1707Max memory usage during epoch 95: 471.25390625 MiB
# 150/150 [==============================] - 616s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3786 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.0924 - mrcnn_class_loss: 0.0344 - mrcnn_bbox_loss: 0.0750 - mrcnn_mask_loss: 0.1707 - val_loss: 0.8564 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.3028 - val_mrcnn_class_loss: 0.0636 - val_mrcnn_bbox_loss: 0.2129 - val_mrcnn_mask_loss: 0.2485 - memory_usage: 471.2539
# Epoch 96/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3823 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0941 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0757 - mrcnn_mask_loss: 0.1734Max memory usage during epoch 96: 480.453125 MiB
# 150/150 [==============================] - 611s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3823 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0941 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0757 - mrcnn_mask_loss: 0.1734 - val_loss: 0.7560 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.2531 - val_mrcnn_class_loss: 0.0578 - val_mrcnn_bbox_loss: 0.1896 - val_mrcnn_mask_loss: 0.2324 - memory_usage: 480.4531
# Epoch 97/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3535 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0801 - mrcnn_class_loss: 0.0286 - mrcnn_bbox_loss: 0.0723 - mrcnn_mask_loss: 0.1665Max memory usage during epoch 97: 466.14453125 MiB
# 150/150 [==============================] - 546s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3535 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0801 - mrcnn_class_loss: 0.0286 - mrcnn_bbox_loss: 0.0723 - mrcnn_mask_loss: 0.1665 - val_loss: 0.9858 - val_rpn_class_loss: 0.0122 - val_rpn_bbox_loss: 0.3949 - val_mrcnn_class_loss: 0.0579 - val_mrcnn_bbox_loss: 0.2428 - val_mrcnn_mask_loss: 0.2587 - memory_usage: 466.1445
# Epoch 98/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3507 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.0860 - mrcnn_class_loss: 0.0309 - mrcnn_bbox_loss: 0.0663 - mrcnn_mask_loss: 0.1610Max memory usage during epoch 98: 475.09375 MiB
# 150/150 [==============================] - 545s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3507 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.0860 - mrcnn_class_loss: 0.0309 - mrcnn_bbox_loss: 0.0663 - mrcnn_mask_loss: 0.1610 - val_loss: 1.0714 - val_rpn_class_loss: 0.0145 - val_rpn_bbox_loss: 0.4531 - val_mrcnn_class_loss: 0.0465 - val_mrcnn_bbox_loss: 0.2596 - val_mrcnn_mask_loss: 0.2767 - memory_usage: 475.0938
# Epoch 99/100
# 151/150 [==============================] - ETA: 0s - batch: 75.0000 - size: 3.0000 - loss: 0.3543 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.0792 - mrcnn_class_loss: 0.0280 - mrcnn_bbox_loss: 0.0735 - mrcnn_mask_loss: 0.1677Max memory usage during epoch 99: 481.29296875 MiB
# 150/150 [==============================] - 541s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3543 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.0792 - mrcnn_class_loss: 0.0280 - mrcnn_bbox_loss: 0.0735 - mrcnn_mask_loss: 0.1677 - val_loss: 0.8823 - val_rpn_class_loss: 0.0107 - val_rpn_bbox_loss: 0.3302 - val_mrcnn_class_loss: 0.0519 - val_mrcnn_bbox_loss: 0.2279 - val_mrcnn_mask_loss: 0.2443 - memory_usage: 481.2930
# Epoch 100/100
# 151/150 [==============================] - ETA: -1s - batch: 75.0000 - size: 3.0000 - loss: 0.3639 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0976 - mrcnn_class_loss: 0.0287 - mrcnn_bbox_loss: 0.0684 - mrcnn_mask_loss: 0.1633Max memory usage during epoch 100: 488.6171875 MiB
# 150/150 [==============================] - 541s 4s/step - batch: 75.0000 - size: 3.0000 - loss: 0.3639 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0976 - mrcnn_class_loss: 0.0287 - mrcnn_bbox_loss: 0.0684 - mrcnn_mask_loss: 0.1633 - val_loss: 0.9270 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.3824 - val_mrcnn_class_loss: 0.0549 - val_mrcnn_bbox_loss: 0.2124 - val_mrcnn_mask_loss: 0.2483 - memory_usage: 488.6172
#
# Model saved at c:\Users\Artryan Nero Logarta\OneDrive - Mapúa University\24-25\2Q\MCS612\Automated-Poultry-Disease-Detection-from-Fecal-Images-Using-Mask-R-CNN\mask_rcnn_poultry.h5
#
# Training time: 53897.67 seconds

# %% [markdown]
# ## Evaluate

# %%
class InferenceConfig(Config):
    NAME = "class-labels"
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    IMAGE_MIN_DIM = 128
    IMAGE_MAX_DIM = 512
    NUM_CLASSES = 1 + 4  # Background + 4 disease classes
    DETECTION_MIN_CONFIDENCE = 0.1  # Lower to include more predictions

config = InferenceConfig()

# %%
model = modellib.MaskRCNN(mode="inference", config=config, model_dir=ROOT_DIR)
model.load_weights(WEIGHTS_PATH, by_name=True)

# %%
def evaluate_model(model, dataset, config):
    """Evaluate the Mask R-CNN model and print various metrics."""

    APs = []
    gt_all = []
    pred_all = []
    with tqdm(dataset.image_ids, desc="Evaluating images", leave=True) as pbar:
        for image_id in pbar:
            # Load image and ground truth data
            image, image_meta, gt_class_id, gt_bbox, gt_mask = modellib.load_image_gt(
                dataset, config, image_id
            )

            # Run object detection
            results = model.detect([image], verbose=0)
            r = results[0]

            # Compute AP
            AP, precisions, recalls, _, iou_threshold, conf = utils.compute_ap(
                gt_bbox, gt_class_id, gt_mask, r["rois"], r["class_ids"], r["scores"], r["masks"]
            )
            APs.append(AP)

            # Store ground truth and predicted class IDs
            gt_labels = gt_class_id.tolist()
            pred_labels = r["class_ids"].tolist()

            # Ensure lengths match
            max_len = max(len(gt_labels), len(pred_labels))

            # Pad with background class (0) where necessary
            gt_labels += [0] * (max_len - len(gt_labels))
            pred_labels += [0] * (max_len - len(pred_labels))

            gt_all.extend(gt_labels)
            pred_all.extend(pred_labels)

            # Update the progress bar with current image stats
            prec = precisions[-2]
            rec = recalls[-2]
            conf = np.array(conf)
            conf_str = "[" + "][".join(", ".join(map(str, row)) for row in conf) + "]"

            pbar.set_postfix(
                image_id=image_id, 
                AP=f"{AP:.3f}", 
                Precision=f"{prec:.3f}", 
                Recall=f"{rec:.3f}", 
                ConfMatrix=f"{conf_str}"
            )
            
        

    print(f"\n📊 Summary Results:")
    print(f"\n--------------------------------------------")
    # Compute Mean Average Precision (mAP)
    mean_ap = np.mean(APs)
    print(f"\nMean Average Precision (mAP): {mean_ap:.4f}")

    # Compute Confusion Matrix
    cm = confusion_matrix(gt_all, pred_all, labels=[0, 1, 2, 3, 4, 5])
    print("\nFinal Confusion Matrix:\n", cm)

    # Compute Accuracy
    accuracy = accuracy_score(gt_all, pred_all)
    print(f"\nOverall Accuracy: {accuracy:.4f}")

    # Compute Precision, Recall, and F1-score
    print("\nClassification Report:")
    print(classification_report(gt_all, pred_all, labels=[1, 2, 3, 4], target_names=CLASS_NAMES[1:]))

    return mean_ap, cm, accuracy

# Run evaluation
_, _, _ = evaluate_model(model, dataset_val, config)
# Out:
# Evaluating images: 100%|██████████| 240/240 [01:18<00:00,  3.04it/s, AP=1.000, ConfMatrix=[1], Precision=1.000, Recall=1.000, image_id=239]
# 📊 Summary Results:
#
# --------------------------------------------
#
# Mean Average Precision (mAP): 0.8356
#
# Final Confusion Matrix:
#  [[  0  20  23 118  55   0]
#  [  5  59   0   3   1   0]
#  [  0   0  54   8   3   0]
#  [  2   0   4  58   1   0]
#  [  0   0   0   7  53   0]
#  [  0   0   0   0   0   0]]
#
# Overall Accuracy: 0.4726
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        cocci       0.75      0.87      0.80        68
#      healthy       0.67      0.83      0.74        65
#          ncd       0.30      0.89      0.45        65
#        salmo       0.47      0.88      0.61        60
#
#    micro avg       0.48      0.87      0.62       258
#    macro avg       0.55      0.87      0.65       258
# weighted avg       0.55      0.87      0.65       258
